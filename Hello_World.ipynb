# %%
# !pip install ollama

# %%
import ollama
first_response = ollama.chat(
    model = "qwen2.5:1.5b",
    messages = [{"role": "user", "content": "Hi, Qwen2.5!"}],
    stream = True
)
for i in first_response:
    print(i["message"]["content"], end = "", flush = True)
# Out:
# Hello! How can I help you today?
